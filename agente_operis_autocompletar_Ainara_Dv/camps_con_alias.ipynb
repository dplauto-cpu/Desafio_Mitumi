# %% [markdown]
# ## TABLA COMPLETA DE CAMPOS CON ALIAS
#
# | Tabla | Campo BD | Alias / sinónimos detectables |
# |-------|----------|-------------------------------|
# | **clientes** | `cliente` | cliente, empresa, organizador, nombre del cliente, razón social |
# | | `email` | email, correo, mail, email de contacto |
# | | `telefono` | teléfono, telefono, móvil, contacto telefónico |
# | **eventos** | `nombre_evento` | nombre del evento, evento, nombre, título del evento, título |
# | | `ciudad` | ciudad, localidad, municipio, ubicación, lugar |
# | | `fecha_inicio` | fecha inicio, fecha de inicio, inicio, fecha desde, desde |
# | | `fecha_fin` | fecha fin, fecha de fin, fin, fecha hasta, hasta |
# | | `numero_personas` | número de asistentes, numero de asistentes, aforo, asistentes, nº personas, numero personas, cantidad de personas |
# | | `servicio_requerido` | servicio requerido, servicios, servicio, tipo de servicio, necesidad |
# | | `presupuesto_maximo` | presupuesto máximo, presupuesto maximo, presupuesto, límite presupuestario, máximo presupuesto |
# | | `tipo_evento` | tipo de evento, formato, categoría, categoria, clasificación |
# | | `nota` | nota, observaciones, comentarios, notas adicionales |
# | | `id_estado` | (se asigna automáticamente según estado detectado) |
# | **presupuestos** | `estado_presupuesto` | estado del presupuesto, estado, situación |
# | | `total` | total, importe total, coste total, precio total |
# | | `fecha` | fecha presupuesto, fecha del presupuesto |
# | | `ubicacion` | ubicación, lugar, dirección, espacio |
# | | `catering` | catering, comida, almuerzo, restauración |
# | | `audiovisuales` | audiovisuales, equipo audiovisual, sonido, proyección, pantalla |
# | | `otros` | otros, gastos adicionales, extras, servicios extra |
# | | `Observaciones` | observaciones, notas del presupuesto, comentarios |
# | **ponentes** | `nombre_ponente` | ponente, nombre del ponente, conferenciante, nombre, speaker |
# | | `docu_identificacion` | documento identificación, dni, nie, documento, identificación |
# | | `email` | email ponente, correo ponente, mail ponente |
# | | `sector` | sector, área, especialidad, campo |
# | | `telefono` | teléfono ponente, telefono ponente, móvil ponente |
# | | `foto_link` | foto, imagen, link foto, url foto |
# | **evento_ponente** | `horario_ida_transporte` | hora ida transporte, ida transporte, salida transporte |
# | | `horario_vuelta_transporte` | hora vuelta transporte, vuelta transporte, regreso transporte |
# | | `localizacion_hotel` | hotel, alojamiento, localización hotel |
# | | `horario_ponencia` | hora ponencia, horario de ponencia, turno ponencia |
# | | `checkin_horario` | checkin, hora checkin, registro |
# | | `ponente_estado` | estado ponente, confirmación ponente |
# | | `presentacion_link` | presentación, link presentación, ppt, diapositivas |
# | | `billete_ida_link` | billete ida, link ida, transporte ida |
# | | `billete_vuelta_link` | billete vuelta, link vuelta, transporte vuelta |
# | **espacios** | `nombre_espacio` | nombre espacio, espacio, sala, auditorio |
# | | `ciudad` | (ya incluido en eventos) |
# | | `direccion` | dirección, dirección espacio |
# | | `capacidad_total` | capacidad, capacidad total, aforo total |
# | | `aforo` | aforo, aforo espacio |
# | | `telefono_contacto` | teléfono contacto, contacto teléfono |
# | | `nombre_contacto` | nombre contacto, contacto |
# | | `email_contacto` | email contacto, correo contacto |
# | **estados** | `descripcion` | estado, descripción estado, situación |
