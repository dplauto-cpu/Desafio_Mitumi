# %% [markdown]
# # Estructura del proyecto: event_ai_agents
#
# event_ai_agents/
# │
# ├── agents/ # Módulo de agentes
# │ ├── pycache/ # Caché de Python (ignorar)
# │ └── briefing_agent.py # Agente Operis (procesamiento de documentos)
# │
# ├── knowledge/ # Base de conocimiento auxiliar
# │ ├── pycache/ # Caché de Python (ignorar)
# │ ├── cities.py # Datos de ciudades (para eventos)
# │ ├── event_types.py # Tipos de eventos (clasificación)
# │ └── field_aliases.py # Aliases de campos (mapeo de formularios)
# │
# └── app.py # Punto de entrada / orquestador principal
# │
# └──data (api/routes)
# │   ├── events JSONs de salida
